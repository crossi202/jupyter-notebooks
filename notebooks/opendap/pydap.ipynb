# %% [markdown]
# # Pydap client example

# %% [markdown]
# ## Install the Python module

# %% [markdown]
# Install the module from `terradue` channel, containing the fix for the URL encoding (see https://github.com/Terradue/pydap-conda and https://github.com/pydap/pydap/pull/180):

# %%
# !sudo conda install pydap -c terradue -y
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.5.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %% [markdown]
# ## Access a NetCDF remote file

# %%
import sys
from pydap.client import open_url

# %% [markdown]
# Open a remote NetCDF file:

# %%
# Open remote file
nc_file_url = 'https://iaos.opendap.terradue.com/thredds/dodsC/SMOS_SMAP/netCDF/north/2018/20181007_north_mix_sit_v100.nc'
dataset = open_url(nc_file_url)

# %% [markdown]
# List the available keys:

# %%
keys = list(dataset.keys())
for key in keys:
    print(key)
# Out:
# smos_thickness
# smos_thickness_unc
# smap_thickness
# smap_thickness_unc
# combined_thickness
# combined_thickness_unc
# flags

# %% [markdown]
# Read the *smos_thickness* variable:

# %%
smos_thickness = dataset['smos_thickness']

# %% [markdown]
# Print arrays dimensions and shape:

# %%
print(smos_thickness.dimensions)
print(smos_thickness.shape)
# Out:
# ('X', 'Y')
# (896, 608)

# %% [markdown]
# Introspect the variable attributes; they are stored in an attribute appropriately called *attributes*:

# %%
import pprint
pprint.pprint(smos_thickness.attributes)
# Out:
# {'_ChunkSizes': [896, 608],
#  'algorithm_type': 'polarisation based',
#  'long_name': 'sea ice thickness derived from SMOS',
#  'standard_name': 'smos sea ice thickness',
#  'units': 'cm',
#  'valid_max': '50',
#  'valid_min': '0'}

# %%
smos_thickness.units
# Out:
# 'cm'

# %%
smos_thickness[0][0]
# Out:
# <BaseType with data array([-9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
# ...
